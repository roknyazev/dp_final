# %%
import utils as u
import matplotlib.pyplot as plt

mpl_params = {

    'figure.figsize': (25, 13),
}
plt.rcParams.update(mpl_params)
G = u.load_graph()

# %% [markdown]
# # Исходный граф

# %%
u.draw_graph(G)

# %% [markdown]
# # Функция стоимости перевозки N грузов на ребрах разных типов
# При фиксированном расстоянии

# %%
u.draw_price_function(0, 100, 400)
u.draw_price_function(1, 100, 400)
u.draw_price_function(2, 100, 400)

# %%
u.draw_graph(G, ['edges'], arrowstyle='->')

# %%
import networkx as nx
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 import networkx as nx
#       2 # 10 130
# ----> 3 len(list(nx.all_simple_paths(G, 10, 130)))
#
# File ~\Desktop\dp_final\venv\lib\site-packages\networkx\algorithms\simple_paths.py:262, in _all_simple_paths_graph(G, source, targets, cutoff)
#     260 stack = [iter(G[source])]
#     261 while stack:
# --> 262     children = stack[-1]
#     263     child = next(children, None)
#     264     if child is None:
#
# KeyboardInterrupt:

# %%
i = 0
for _ in nx.all_simple_paths(G, 10, 130):
    i += 1
    print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 i = 0
# ----> 2 for _ in nx.all_simple_paths(G, 10, 130):
#       3     i += 1
#       4     print(i)
#
# File ~\Desktop\dp_final\venv\lib\site-packages\networkx\algorithms\simple_paths.py:263, in _all_simple_paths_graph(G, source, targets, cutoff)
#     261 while stack:
#     262     children = stack[-1]
# --> 263     child = next(children, None)
#     264     if child is None:
#     265         stack.pop()
#
# KeyboardInterrupt:
